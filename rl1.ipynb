# %%
# %pip install tensorflow-gpu==2.9.1 tensorflow==2.9.1 stable-baselines3 gym-anytrading gym
# Out:
# Requirement already satisfied: tensorflow-gpu==2.9.1 in c:\users\levir\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: tensorflow==2.9.1 in c:\users\levir\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: stable-baselines3 in c:\users\levir\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: gym-anytrading in c:\users\levir\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: gym in c:\users\levir\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (3.6.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.42.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.12)
# Requirement already satisfied: numpy>=1.20 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (4.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (0.26.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (61.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (3.19.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (14.0.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.6.3)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (0.2.0)
# Requirement already satisfied: packaging in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\levir\anaconda3\lib\site-packages (from tensorflow-gpu==2.9.1) (3.3.0)
# Requirement already satisfied: pandas in c:\users\levir\anaconda3\lib\site-packages (from stable-baselines3) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\levir\anaconda3\lib\site-packages (from stable-baselines3) (3.5.1)
# Requirement already satisfied: torch>=1.8.1 in c:\users\levir\anaconda3\lib\site-packages (from stable-baselines3) (1.13.1)
# Requirement already satisfied: cloudpickle in c:\users\levir\anaconda3\lib\site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\levir\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu==2.9.1) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\levir\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\levir\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2021.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\levir\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\levir\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\levir\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\levir\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\levir\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\levir\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\levir\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\levir\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\levir\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\levir\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\levir\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu==2.9.1) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Gym stuff
import gym
import gym_anytrading

# Stable baselines3 library
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\levir\OneDrive\Desktop\DataSets\kaggle_ethereum_data\ETH-USD.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0   11/9/2017  308.644989  329.451996  307.056000  320.884003  320.884003
# 1  11/10/2017  320.670990  324.717987  294.541992  299.252991  299.252991
# 2  11/11/2017  298.585999  319.453003  298.191986  314.681000  314.681000
# 3  11/12/2017  314.690002  319.153015  298.513000  307.907990  307.907990
# 4  11/13/2017  307.024994  328.415009  307.024994  316.716003  316.716003
#
#        Volume
# 0   893249984
# 1   885985984
# 2   842300992
# 3  1613479936
# 4  1041889984

# %%
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1598 entries, 0 to 1597
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1598 non-null   object
#  1   Open       1598 non-null   float64
#  2   High       1598 non-null   float64
#  3   Low        1598 non-null   float64
#  4   Close      1598 non-null   float64
#  5   Adj Close  1598 non-null   float64
#  6   Volume     1598 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 87.5+ KB

# %%
# We attempted to lower the detail in our data to get more memory since our kernel kept crashing.
#df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].astype('float32')
#print(df.dtypes)

# %%
# Checking data types to see if we need any type conversions
df['Date'] = pd.to_datetime(df['Date'])

# %%
# We do this now so our data is in chronological order and going from past -> present, previously it was reversed. This needs to be put in place before we make actions in our environment.
# Updating present dataframe and not making a copy. We're also setting our index. Basically the key value other values are associated with or stem from.
df.sort_values('Date', ascending=True, inplace=True)
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003  320.884003
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
#
#                 Volume
# Date
# 2017-11-09   893249984
# 2017-11-10   885985984
# 2017-11-11   842300992
# 2017-11-12  1613479936
# 2017-11-13  1041889984

# %%
# We don't need adjusted close price so we'll drop it from the data
df = df.drop('Adj Close', axis=1)
df.head()
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
# Creating environement for reinforcement learning bot to learn how to trade.
# Window_size is time steps for reference data for prediction, referencing previous data entries starting from prediction
# Hypothesis, higher window_size == more accurate prediction
# stocks-v0 is a trading enviornment built by library stable baselines
env = gym.make('stocks-v0', df=df, frame_bound=(5,250), window_size=5)

# %%
env.signal_features
# Out:
# array([[ 3.20884003e+02,  0.00000000e+00],
#        [ 2.99252991e+02, -2.16310120e+01],
#        [ 3.14681000e+02,  1.54280090e+01],
#        [ 3.07907990e+02, -6.77301000e+00],
#        [ 3.16716003e+02,  8.80801300e+00],
#        [ 3.37631012e+02,  2.09150090e+01],
#        [ 3.33356995e+02, -4.27401700e+00],
#        [ 3.30924011e+02, -2.43298400e+00],
#        [ 3.32394012e+02,  1.47000100e+00],
#        [ 3.47612000e+02,  1.52179880e+01],
#        [ 3.54385986e+02,  6.77398600e+00],
#        [ 3.66730011e+02,  1.23440250e+01],
#        [ 3.60401001e+02, -6.32901000e+00],
#        [ 3.80652008e+02,  2.02510070e+01],
#        [ 4.10165985e+02,  2.95139770e+01],
#        [ 4.74911011e+02,  6.47450260e+01],
#        [ 4.66276001e+02, -8.63501000e+00],
#        [ 4.71329987e+02,  5.05398600e+00],
#        [ 4.80355011e+02,  9.02502400e+00],
#        [ 4.72902008e+02, -7.45300300e+00],
#        [ 4.27523010e+02, -4.53789980e+01],
#        [ 4.47114014e+02,  1.95910040e+01],
#        [ 4.66540009e+02,  1.94259950e+01],
#        [ 4.63449005e+02, -3.09100400e+00],
#        [ 4.65852997e+02,  2.40399200e+00],
#        [ 4.70204010e+02,  4.35101300e+00],
#        [ 4.63281006e+02, -6.92300400e+00],
#        [ 4.28588013e+02, -3.46929930e+01],
#        [ 4.34407990e+02,  5.81997700e+00],
#        [ 4.56031006e+02,  2.16230160e+01],
#        [ 4.73502014e+02,  1.74710080e+01],
#        [ 4.41721008e+02, -3.17810060e+01],
#        [ 5.15135986e+02,  7.34149780e+01],
#        [ 6.09302979e+02,  1.63179940e+01],
#        [ 6.07124023e+02, -2.17895600e+00],
#        [ 6.05187012e+02, -1.93701100e+00],
#        [ 6.01077026e+02, -4.10998600e+00],
#        [ 5.97562012e+02, -3.51501400e+00],
#        [ 5.26479004e+02, -7.10830080e+01],
#        [ 5.33283997e+02,  6.80499300e+00],
#        [ 4.96842987e+02, -3.64410100e+01],
#        [ 4.77493988e+02, -1.93489990e+01],
#        [ 5.19742004e+02,  4.22480160e+01],
#        [ 4.91003998e+02, -2.87380060e+01],
#        [ 4.99641998e+02,  8.63800000e+00],
#        [ 5.00447998e+02,  8.06000000e-01],
#        [ 5.18890991e+02,  1.84429930e+01],
#        [ 5.37956970e+02,  1.90659790e+01],
#        [ 5.36268005e+02, -1.68896500e+00],
#        [ 5.27367004e+02, -8.90100100e+00],
#        [ 4.65816986e+02, -6.15500180e+01],
#        [ 4.74519989e+02,  8.70300300e+00],
#        [ 4.57671997e+02, -1.68479920e+01],
#        [ 4.60309998e+02,  2.63800100e+00],
#        [ 4.32772003e+02, -2.75379950e+01],
#        [ 4.42364990e+02,  9.59298700e+00],
#        [ 4.22364990e+02, -2.00000000e+01],
#        [ 4.36009003e+02,  1.36440130e+01],
#        [ 4.55179993e+02,  1.91709900e+01],
#        [ 4.53917999e+02, -1.26199400e+00],
#        [ 4.75346985e+02,  2.14289860e+01],
#        [ 4.64195007e+02, -1.11519780e+01],
#        [ 4.67317993e+02,  3.12298600e+00],
#        [ 4.74411987e+02,  7.09399400e+00],
#        [ 4.74011993e+02, -3.99994000e-01],
#        [ 4.91660004e+02,  1.76480110e+01],
#        [ 4.89118988e+02, -2.54101600e+00],
#        [ 4.76682007e+02, -1.24369810e+01],
#        [ 4.34424011e+02, -4.22579960e+01],
#        [ 4.46518005e+02,  1.20939940e+01],
#        [ 4.30074005e+02, -1.64440000e+01],
#        [ 4.34027008e+02,  3.95300300e+00],
#        [ 4.36085999e+02,  2.05899100e+00],
#        [ 4.49850006e+02,  1.37640070e+01],
#        [ 4.80657990e+02,  3.08079840e+01]])

# %%
# This shows us the quantitity of actions within our enviornment, we're in a stock trading environment which has the actions buy and sell, we only have long and short positions
# Sell=0
# Buy=1
# More info -> https://github.com/AminHP/gym-anytrading
env.action_space
# Out:
# Discrete(2)

# %%
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
#plt.figure(figsize=(15,6))
#plt.cla()
#env.render_all()
#plt.show()
# Out:
# info {'total_reward': -272.3791809999994, 'total_profit': 0.23241507953026172, 'position': 0}

# %%
# %pip install finta
# Out:
# Requirement already satisfied: finta in c:\users\levir\anaconda3\lib\site-packages (1.3)
# Requirement already satisfied: numpy in c:\users\levir\anaconda3\lib\site-packages (from finta) (1.21.5)
# Requirement already satisfied: pandas in c:\users\levir\anaconda3\lib\site-packages (from finta) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\levir\anaconda3\lib\site-packages (from pandas->finta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\levir\anaconda3\lib\site-packages (from pandas->finta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\levir\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->finta) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gym_anytrading.envs import StocksEnv
from finta import TA

# %%
df['SMA'] = TA.SMA(df, 12)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df.fillna(0, inplace=True)

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Low', 'Volume','SMA', 'RSI', 'OBV']].to_numpy()[start:end]
    return prices, signal_features

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df, window_size=12, frame_bound=(12,50))

# %%
env2.signal_features
# Out:
# array([[ 3.07056000e+02,  8.93249984e+08,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 2.94541992e+02,  8.85985984e+08,  0.00000000e+00,
#          0.00000000e+00, -8.85985984e+08],
#        [ 2.98191986e+02,  8.42300992e+08,  0.00000000e+00,
#          4.34421109e+01, -4.36849920e+07],
#        [ 2.98513000e+02,  1.61347994e+09,  0.00000000e+00,
#          3.60400477e+01, -1.65716493e+09],
#        [ 3.07024994e+02,  1.04188998e+09,  0.00000000e+00,
#          4.83622903e+01, -6.15274944e+08],
#        [ 3.16763000e+02,  1.06968000e+09,  0.00000000e+00,
#          6.54055550e+01,  4.54405056e+08],
#        [ 3.29812988e+02,  7.22665984e+08,  0.00000000e+00,
#          6.09764989e+01, -2.68260928e+08],
#        [ 3.23605988e+02,  7.97254016e+08,  0.00000000e+00,
#          5.85460751e+01, -1.06551494e+09],
#        [ 3.27523010e+02,  6.21732992e+08,  0.00000000e+00,
#          5.95939960e+01, -4.43781952e+08],
#        [ 3.27687012e+02,  6.49638976e+08,  0.00000000e+00,
#          6.84778747e+01,  2.05857024e+08],
#        [ 3.44739990e+02,  1.18152998e+09,  0.00000000e+00,
#          7.14834364e+01,  1.38738701e+09],
#        [ 3.53289001e+02,  8.07027008e+08,  3.30206334e+02,
#          7.59782525e+01,  2.19441402e+09],
#        [ 3.50692993e+02,  9.49912000e+08,  3.33499418e+02,
#          6.98951459e+01,  1.24450202e+09],
#        [ 3.60147003e+02,  8.00819008e+08,  3.40282669e+02,
#          7.64047695e+01,  2.04532102e+09],
#        [ 3.76088013e+02,  1.84568000e+09,  3.48239751e+02,
#          8.23834568e+01,  3.89100102e+09],
#        [ 4.02757996e+02,  2.29282995e+09,  3.62156670e+02,
#          8.89800965e+01,  6.18383098e+09],
#        [ 4.61053009e+02,  1.42208000e+09,  3.74620003e+02,
#          8.44387466e+01,  4.76175098e+09],
#        [ 4.51605988e+02,  1.19777997e+09,  3.85761584e+02,
#          8.49237462e+01,  5.95953094e+09],
#        [ 4.68484985e+02,  1.39648000e+09,  3.98011419e+02,
#          8.57762753e+01,  7.35601094e+09],
#        [ 4.66346985e+02,  1.34649997e+09,  4.09842918e+02,
#          8.16691190e+01,  6.00951098e+09],
#        [ 4.25071014e+02,  2.67594010e+09,  4.17770335e+02,
#          6.21546765e+01,  3.33357088e+09],
#        [ 7.60934998e+02,  2.20115994e+09,  7.49192830e+02,
#          6.47527649e+01,  2.54360877e+10],
#        [ 7.38413025e+02,  2.10002995e+09,  7.55725662e+02,
#          6.32240891e+01,  2.33360577e+10],
#        [ 7.01187012e+02,  2.38914995e+09,  7.59126831e+02,
#          5.96618668e+01,  2.09469078e+10]])

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
model = A2C('MlpPolicy', env, verbose=1) 
model.learn(total_timesteps=10000)#00
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 1250     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0.027    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 11.5     |
# |    value_loss         | 1.17e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1202     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | -0.213   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 43.2     |
# |    value_loss         | 4.83e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1239     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | -3.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.165   |
# |    value_loss         | 0.377    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1252     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0.00178  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -21.1    |
# |    value_loss         | 1.09e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1265     |
# |    iterations         | 500      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.592   |
# |    explained_variance | 0.0163   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.85     |
# |    value_loss         | 105      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1267      |
# |    iterations         | 600       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.669    |
# |    explained_variance | -0.000489 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 85.5      |
# |    value_loss         | 1.15e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1272     |
# |    iterations         | 700      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.516   |
# |    explained_variance | -0.408   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.117    |
# |    value_loss         | 0.31     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1281     |
# |    iterations         | 800      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.495   |
# |    explained_variance | -22.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -1.55    |
# |    value_loss         | 15.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1260     |
# |    iterations         | 900      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.382   |
# |    explained_variance | 0.303    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 7.95     |
# |    value_loss         | 1.11e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1200     |
# |    iterations         | 1000     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.438   |
# |    explained_variance | 0.0643   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -29.3    |
# |    value_loss         | 2.4e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1189     |
# |    iterations         | 1100     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.546   |
# |    explained_variance | -0.031   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 14.9     |
# |    value_loss         | 1.33e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1187     |
# |    iterations         | 1200     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.35    |
# |    explained_variance | 0.0388   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 45.6     |
# |    value_loss         | 5.23e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1196     |
# |    iterations         | 1300     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.505   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.461   |
# |    value_loss         | 0.422    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1207     |
# |    iterations         | 1400     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.339   |
# |    explained_variance | 0.169    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.77     |
# |    value_loss         | 797      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1218     |
# |    iterations         | 1500     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.454   |
# |    explained_variance | 0.314    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 19.1     |
# |    value_loss         | 3.98e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1221     |
# |    iterations         | 1600     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.221   |
# |    explained_variance | 0.192    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.94     |
# |    value_loss         | 1.55e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1227     |
# |    iterations         | 1700     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | -0.00729 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 6.49     |
# |    value_loss         | 4.23e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1230     |
# |    iterations         | 1800     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.289   |
# |    explained_variance | 0.247    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 1.81     |
# |    value_loss         | 1.29e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1232      |
# |    iterations         | 1900      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.295    |
# |    explained_variance | -0.000111 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 76.1      |
# |    value_loss         | 1.91e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1235     |
# |    iterations         | 2000     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.279   |
# |    explained_variance | 0.00035  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.38     |
# |    value_loss         | 953      |
# ------------------------------------

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(80,250))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': -433.0979610000001, 'total_profit': 0.3499950935865232, 'position': 0}
